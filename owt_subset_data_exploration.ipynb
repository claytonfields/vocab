# %% [markdown]
# # data_exploration

# %% [markdown]
# ### childes

# %%
import re
import os
import glob
from pathlib import Path

# %%
#open text file in read mode
with open("data/childes/aochildes.txt", "r") as text_file:

    #read whole file to a string
    data = text_file.read()
    data = data.lower()

print(len(data))

# words =  re.split('[^ \w -./,$]',data)
# words = data.split()
len(words)
# Out:
# 21457727
# 4960141

# %%
vocab = set(words)
len(vocab)
# Out:
# 27723

# %%
vocab
# Out:
# {'pin',
#  'suppress',
#  'suffocating',
#  "bob'll",
#  'host',
#  "those'll",
#  'human',
#  "alec's",
#  'nipping',
#  'rub',
#  "craig's",
#  "paddle's",
#  'manilow',
#  'abluablu',
#  'dabadabadoo',
#  'reckon',
#  'links',
#  'dips',
#  'lacrosse',
#  'revealed',
#  'laden',
#  "melanie's",
#  'gondola',
#  'humpback',
#  "anything'd",
#  'flesh',
#  'casinos',
#  'squeal',
#  'rarah',
#  'peeka',
#  'errands',
#  'seals',
#  'subway',
#  'sacrifice',
#  'obey',
#  'dropping',
#  'waddled',
#  "jenessa's",
#  'shwoop',
#  "second's",
#  'gknow',
#  'docile',
#  'brocco',
#  'habugubuh',
#  'brambles',
#  'screwing',
#  'veal',
#  'feisty',
#  'aunt',
#  'female',
#  'sweetness',
#  'herb',
#  'drool',
#  'blazing',
#  'stewed',
#  'scrubbie',
#  'composer',
#  'chom',
#  'doodie',
#  'shady',
#  'windpipe',
#  'funniest',
#  'crabbie',
#  'coolest',
#  'grooming',
#  'opossum',
#  'universal',
#  'dance',
#  'mamaless',
#  'stung',
#  'coffin',
#  'driveway',
#  'compost',
# ...

# %%
# data

# %% [markdown]
# ### owt subset

# %%
owt_data_path = os.path.join('data','openwebtext_subset')
owt_data_path = Path(data_path)
owt_files = [str(pp) for pp in owt_data_path.glob("**/*.txt")]

# owt_data = ''
# for file in owt_files:
#     with open(file, 'r') as text_file:
#         ' '.join([owt_data, str(text_file)])
        
with open("owt_subset.txt", "w",  encoding='utf-8') as outfile:
    for filename in owt_files:
         with open(filename,'r', encoding='utf-8') as infile:

            contents = infile.read()

            outfile.write(contents)
        
        
# owt_data[:150]
# data_path

# %%
len(owt_files)
# Out:
# 6208
