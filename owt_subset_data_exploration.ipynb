# %% [markdown]
# # owt_subset_data_exploration

# %%
import re
import os

# %%
#open text file in read mode

# data_dir = 'aochildes.txt'
# data_path = os.path.join('data',data_dir)
# files = file_paths = glob.glob("aochildes/*.txt")
data_path = 'data/childes/aochildes.txt'
with open(data_path, "r") as text_file:

    #read whole file to a string
    data = text_file.read()
    data = data.lower()

print(len(data))
# Out:
# 21457727

# %%
# words =  re.split('[^ \w -./,$]',data)
words = data.split()
len(words)
# Out:
# 4960141

# %%
vocab = set(words)
len(vocab)
# Out:
# 27723

# %%
vocab
# Out:
# {'jumping',
#  'clamming',
#  'addressing',
#  'vim',
#  'walla',
#  'miller',
#  'argument',
#  'tttt',
#  'oli',
#  'fourteenth',
#  'oldies',
#  'frolic',
#  'wayland',
#  'duckbills',
#  'scrumptious',
#  'hydrants',
#  'ajax',
#  'container',
#  'wouja',
#  'twas',
#  "there've",
#  'shedding',
#  "azalea's",
#  'orbit',
#  'tables',
#  'ringers',
#  'graylock',
#  'ears',
#  'lilies',
#  'masta',
#  'moooooooooooo',
#  'veena',
#  'vessel',
#  'omelet',
#  'salami',
#  'snuffie',
#  "weaver's",
#  'seated',
#  'left',
#  'fir',
#  'racquet',
#  'vie',
#  'houses',
#  'believes',
#  "harvey's",
#  'dang',
#  'bookbag',
#  "cold's",
#  'hitter',
#  "simba's",
#  'kelley',
#  'halloween',
#  'grammie',
#  'frustrates',
#  'amina',
#  "chico's",
#  'farmer',
#  'earn',
#  'adoodoodoo',
#  'grumerate',
#  'lory',
#  'operation',
#  'pengams',
#  'samicircle',
#  'according',
#  'condolences',
#  'sprinkling',
#  'flips',
#  'opps',
#  'prickers',
#  'superman',
#  'rehook',
# ...
